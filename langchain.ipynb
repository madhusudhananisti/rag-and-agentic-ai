# %%
# !pip install --force-reinstall --no-cache-dir tenacity==8.2.3 --user
# !pip install "ibm-watsonx-ai==1.0.8" --user
# !pip install "ibm-watson-machine-learning==1.0.367" --user
# !pip install "langchain-ibm==0.1.7" --user
# !pip install "langchain-community==0.2.10" --user
# !pip install "langchain-experimental==0.0.62" --user
# !pip install "langchainhub==0.1.18" --user
# !pip install "langchain==0.2.11" --user
# !pip install "pypdf==4.2.0" --user
# !pip install "chromadb==0.4.24" --user
# Out:
# Collecting tenacity==8.2.3
#   Downloading tenacity-8.2.3-py3-none-any.whl.metadata (1.0 kB)
# Downloading tenacity-8.2.3-py3-none-any.whl (24 kB)
# Installing collected packages: tenacity
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.1.2
#     Uninstalling tenacity-9.1.2:
#       Successfully uninstalled tenacity-9.1.2
# Successfully installed tenacity-8.2.3
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: C:\Users\Dell\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Collecting ibm-watsonx-ai==1.0.8
#   Downloading ibm_watsonx_ai-1.0.8-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: requests in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from ibm-watsonx-ai==1.0.8) (2.32.5)
# Requirement already satisfied: urllib3 in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from ibm-watsonx-ai==1.0.8) (2.5.0)
# Collecting pandas<2.2.0,>=0.24.2 (from ibm-watsonx-ai==1.0.8)
#   Downloading pandas-2.1.4.tar.gz (4.3 MB)
#      ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#      -- ------------------------------------- 0.3/4.3 MB ? eta -:--:--
#      ------- -------------------------------- 0.8/4.3 MB 1.9 MB/s eta 0:00:02
#      ------- -------------------------------- 0.8/4.3 MB 1.9 MB/s eta 0:00:02
#      ------- -------------------------------- 0.8/4.3 MB 1.9 MB/s eta 0:00:02
#      ------- -------------------------------- 0.8/4.3 MB 1.9 MB/s eta 0:00:02
#      --------- ------------------------------ 1.0/4.3 MB 737.1 kB/s eta 0:00:05
#      --------- ------------------------------ 1.0/4.3 MB 737.1 kB/s eta 0:00:05
#      --------- ------------------------------ 1.0/4.3 MB 737.1 kB/s eta 0:00:05
#      ------------ --------------------------- 1.3/4.3 MB 653.6 kB/s eta 0:00:05
#      ------------ --------------------------- 1.3/4.3 MB 653.6 kB/s eta 0:00:05
#      ------------ --------------------------- 1.3/4.3 MB 653.6 kB/s eta 0:00:05
#      -------------- ------------------------- 1.6/4.3 MB 561.6 kB/s eta 0:00:05
#      ----------------- ---------------------- 1.8/4.3 MB 611.6 kB/s eta 0:00:04
#      ------------------- -------------------- 2.1/4.3 MB 663.0 kB/s eta 0:00:04
#      ---------------------- ----------------- 2.4/4.3 MB 698.2 kB/s eta 0:00:03
#      ------------------------ --------------- 2.6/4.3 MB 734.6 kB/s eta 0:00:03
#      -------------------------- ------------- 2.9/4.3 MB 780.4 kB/s eta 0:00:02
#      ------------------------------- -------- 3.4/4.3 MB 860.7 kB/s eta 0:00:02
#      ---------------------------------- ----- 3.7/4.3 MB 900.4 kB/s eta 0:00:01
#      ------------------------------------ --- 3.9/4.3 MB 935.1 kB/s eta 0:00:01
#      ---------------------------------------- 4.3/4.3 MB 952.3 kB/s  0:00:04
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × installing build dependencies for pandas did not run successfully.
#   │ exit code: 1
#   ╰─> [102 lines of output]
#       Ignoring oldest-supported-numpy: markers 'python_version < "3.12"' don't match your environment
#       Collecting meson-python==0.13.1
#         Downloading meson_python-0.13.1-py3-none-any.whl.metadata (4.1 kB)
#       Collecting meson==1.2.1
#         Downloading meson-1.2.1-py3-none-any.whl.metadata (1.7 kB)
#       Collecting wheel
#         Downloading wheel-0.48.0-py3-none-any.whl.metadata (2.3 kB)
#       Collecting Cython<3,>=0.29.33
#         Downloading Cython-0.29.37-py2.py3-none-any.whl.metadata (3.1 kB)
#       Collecting numpy<2,>=1.26.0
#         Downloading numpy-1.26.4.tar.gz (15.8 MB)
#            ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#             --------------------------------------- 0.3/15.8 MB ? eta -:--:--
#            - -------------------------------------- 0.5/15.8 MB 1.8 MB/s eta 0:00:09
#            -- ------------------------------------- 1.0/15.8 MB 2.2 MB/s eta 0:00:07
#            --- ------------------------------------ 1.6/15.8 MB 2.0 MB/s eta 0:00:07
#            ---- ----------------------------------- 1.8/15.8 MB 2.1 MB/s eta 0:00:07
#            ----- ---------------------------------- 2.4/15.8 MB 2.1 MB/s eta 0:00:07
#            ------- -------------------------------- 2.9/15.8 MB 2.2 MB/s eta 0:00:06
#            ------- -------------------------------- 3.1/15.8 MB 2.1 MB/s eta 0:00:06
#            --------- ------------------------------ 3.7/15.8 MB 2.1 MB/s eta 0:00:06
#            ---------- ----------------------------- 4.2/15.8 MB 2.1 MB/s eta 0:00:06
#            ----------- ---------------------------- 4.5/15.8 MB 2.1 MB/s eta 0:00:06
#            ------------ --------------------------- 5.0/15.8 MB 2.1 MB/s eta 0:00:06
#            ------------ --------------------------- 5.0/15.8 MB 2.1 MB/s eta 0:00:06
#            ------------- -------------------------- 5.2/15.8 MB 1.8 MB/s eta 0:00:06
#            ------------- -------------------------- 5.2/15.8 MB 1.8 MB/s eta 0:00:06
#            ------------- -------------------------- 5.2/15.8 MB 1.8 MB/s eta 0:00:06
#            ------------- -------------------------- 5.2/15.8 MB 1.8 MB/s eta 0:00:06
#            ------------- -------------------------- 5.2/15.8 MB 1.8 MB/s eta 0:00:06
#            ------------- -------------------------- 5.5/15.8 MB 1.4 MB/s eta 0:00:08
#            -------------- ------------------------- 5.8/15.8 MB 1.4 MB/s eta 0:00:08
#            --------------- ------------------------ 6.3/15.8 MB 1.4 MB/s eta 0:00:07
#            ----------------- ---------------------- 6.8/15.8 MB 1.5 MB/s eta 0:00:07
#            ----------------- ---------------------- 7.1/15.8 MB 1.5 MB/s eta 0:00:06
#            ------------------- -------------------- 7.6/15.8 MB 1.5 MB/s eta 0:00:06
#            -------------------- ------------------- 8.1/15.8 MB 1.5 MB/s eta 0:00:05
#            --------------------- ------------------ 8.4/15.8 MB 1.6 MB/s eta 0:00:05
#            --------------------- ------------------ 8.7/15.8 MB 1.6 MB/s eta 0:00:05
#            ----------------------- ---------------- 9.2/15.8 MB 1.6 MB/s eta 0:00:05
#            ----------------------- ---------------- 9.4/15.8 MB 1.6 MB/s eta 0:00:05
#            ------------------------- -------------- 10.0/15.8 MB 1.6 MB/s eta 0:00:04
#            ------------------------- -------------- 10.2/15.8 MB 1.6 MB/s eta 0:00:04
#            --------------------------- ------------ 10.7/15.8 MB 1.6 MB/s eta 0:00:04
#            ---------------------------- ----------- 11.3/15.8 MB 1.6 MB/s eta 0:00:03
#            ----------------------------- ---------- 11.5/15.8 MB 1.6 MB/s eta 0:00:03
#            ----------------------------- ---------- 11.8/15.8 MB 1.6 MB/s eta 0:00:03
#            ------------------------------ --------- 12.1/15.8 MB 1.6 MB/s eta 0:00:03
#            ------------------------------- -------- 12.6/15.8 MB 1.6 MB/s eta 0:00:02
#            -------------------------------- ------- 12.8/15.8 MB 1.6 MB/s eta 0:00:02
#            --------------------------------- ------ 13.4/15.8 MB 1.6 MB/s eta 0:00:02
#            ---------------------------------- ----- 13.6/15.8 MB 1.6 MB/s eta 0:00:02
#            ----------------------------------- ---- 13.9/15.8 MB 1.6 MB/s eta 0:00:02
#            ------------------------------------ --- 14.4/15.8 MB 1.6 MB/s eta 0:00:01
#            ------------------------------------- -- 14.7/15.8 MB 1.7 MB/s eta 0:00:01
#            -------------------------------------- - 15.2/15.8 MB 1.7 MB/s eta 0:00:01
#            ---------------------------------------  15.5/15.8 MB 1.7 MB/s eta 0:00:01
#            ---------------------------------------- 15.8/15.8 MB 1.6 MB/s  0:00:09
#         Installing build dependencies: started
#         Installing build dependencies: finished with status 'done'
#         Getting requirements to build wheel: started
#         Getting requirements to build wheel: finished with status 'done'
#         Installing backend dependencies: started
#         Installing backend dependencies: finished with status 'done'
#         Preparing metadata (pyproject.toml): started
#         Preparing metadata (pyproject.toml): finished with status 'error'
#         error: subprocess-exited-with-error
#
#         Ã— Preparing metadata (pyproject.toml) did not run successfully.
#         â”‚ exit code: 1
#         â•°â”€> [21 lines of output]
#             + C:\Users\Dell\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe C:\Users\Dell\AppData\Local\Temp\pip-install-fvd2fb8k\numpy_de85c781a5494ce7bf341e4f8f478ae9\vendored-meson\meson\meson.py setup C:\Users\Dell\AppData\Local\Temp\pip-install-fvd2fb8k\numpy_de85c781a5494ce7bf341e4f8f478ae9 C:\Users\Dell\AppData\Local\Temp\pip-install-fvd2fb8k\numpy_de85c781a5494ce7bf341e4f8f478ae9\.mesonpy-ct2g542y -Dbuildtype=release -Db_ndebug=if-release -Db_vscrt=md --native-file=C:\Users\Dell\AppData\Local\Temp\pip-install-fvd2fb8k\numpy_de85c781a5494ce7bf341e4f8f478ae9\.mesonpy-ct2g542y\meson-python-native-file.ini
#             The Meson build system
#             Version: 1.2.99
#             Source dir: C:\Users\Dell\AppData\Local\Temp\pip-install-fvd2fb8k\numpy_de85c781a5494ce7bf341e4f8f478ae9
#             Build dir: C:\Users\Dell\AppData\Local\Temp\pip-install-fvd2fb8k\numpy_de85c781a5494ce7bf341e4f8f478ae9\.mesonpy-ct2g542y
#             Build type: native build
#             Project name: NumPy
#             Project version: 1.26.4
#             WARNING: Failed to activate VS environment: Could not parse vswhere.exe output
#
#             ..\meson.build:1:0: ERROR: Unknown compiler(s): [['icl'], ['cl'], ['cc'], ['gcc'], ['clang'], ['clang-cl'], ['pgcc']]
#             The following exception(s) were encountered:
#             Running `icl ""` gave "[WinError 2] The system cannot find the file specified"
#             Running `cl /?` gave "[WinError 2] The system cannot find the file specified"
#             Running `cc --version` gave "[WinError 2] The system cannot find the file specified"
#             Running `gcc --version` gave "[WinError 2] The system cannot find the file specified"
#             Running `clang --version` gave "[WinError 2] The system cannot find the file specified"
#             Running `clang-cl /?` gave "[WinError 2] The system cannot find the file specified"
#             Running `pgcc --version` gave "[WinError 2] The system cannot find the file specified"
#
#             A full log can be found at C:\Users\Dell\AppData\Local\Temp\pip-install-fvd2fb8k\numpy_de85c781a5494ce7bf341e4f8f478ae9\.mesonpy-ct2g542y\meson-logs\meson-log.txt
#             [end of output]
#
#         note: This error originates from a subprocess, and is likely not a problem with pip.
#       error: metadata-generation-failed
#
#       Ã— Encountered error while generating package metadata.
#       â•°â”€> numpy
#
#       note: This is an issue with the package mentioned above, not pip.
#       hint: See above for details.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: C:\Users\Dell\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ERROR: Failed to build 'pandas' when installing build dependencies for pandas
# ERROR: Ignored the following yanked versions: 1.0.8, 1.0.9, 1.0.10, 1.0.14, 1.0.15, 1.0.22, 1.0.28, 1.0.29, 1.0.34, 1.0.38, 1.0.43, 1.0.44, 1.0.45, 1.0.51, 1.0.53, 1.0.57, 1.0.66, 1.0.70, 1.0.77, 1.0.79, 1.0.86, 1.0.91, 1.0.96, 1.0.99, 1.0.100, 1.0.102, 1.0.105, 1.0.115, 1.0.116, 1.0.118, 1.0.120, 1.0.122, 1.0.135, 1.0.139, 1.0.141, 1.0.142, 1.0.157, 1.0.162, 1.0.165, 1.0.166, 1.0.173, 1.0.175, 1.0.176, 1.0.178, 1.0.179, 1.0.180, 1.0.181, 1.0.189, 1.0.200, 1.0.202, 1.0.204, 1.0.206, 1.0.208, 1.0.209, 1.0.210, 1.0.214, 1.0.218, 1.0.222, 1.0.227, 1.0.229, 1.0.232, 1.0.237, 1.0.238, 1.0.244, 1.0.246, 1.0.248, 1.0.250, 1.0.253, 1.0.255, 1.0.256, 1.0.257, 1.0.260, 1.0.262, 1.0.264, 1.0.268, 1.0.272, 1.0.273, 1.0.277, 1.0.280, 1.0.283, 1.0.286, 1.0.288, 1.0.292, 1.0.293, 1.0.294, 1.0.297, 1.0.302, 1.0.307, 1.0.308, 1.0.309, 1.0.310, 1.0.311, 1.0.312, 1.0.313, 1.0.316, 1.0.319, 1.0.320, 1.0.321, 1.0.322, 1.0.324, 1.0.326, 1.0.327, 1.0.330, 1.0.333, 1.0.335, 1.0.338, 1.0.339, 1.0.340, 1.0.342, 1.0.344, 1.0.345, 1.0.347, 1.0.348, 1.0.349, 1.0.351, 1.0.352, 1.0.353, 1.0.354, 1.0.355, 1.0.356, 1.0.357, 1.0.359, 1.0.360, 1.0.364
# ERROR: Ignored the following versions that require a different python version: 1.0.366 Requires-Python >=3.10,<3.13; 1.0.367 Requires-Python >=3.10,<3.13; 1.0.368 Requires-Python >=3.10,<3.13; 1.0.370 Requires-Python >=3.10,<3.13
# ERROR: Could not find a version that satisfies the requirement ibm-watson-machine-learning==1.0.367 (from versions: none)
#
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: C:\Users\Dell\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for ibm-watson-machine-learning==1.0.367
# Collecting langchain-ibm==0.1.7
#   Downloading langchain_ibm-0.1.7-py3-none-any.whl.metadata (5.2 kB)
# Collecting ibm-watsonx-ai<2.0.0,>=1.0.1 (from langchain-ibm==0.1.7)
#   Downloading ibm_watsonx_ai-1.7.2-py3-none-any.whl.metadata (7.7 kB)
# Collecting langchain-core<0.3,>=0.1.50 (from langchain-ibm==0.1.7)
#   Downloading langchain_core-0.2.43-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: requests in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.1->langchain-ibm==0.1.7) (2.32.5)
# Requirement already satisfied: httpx<0.29,>=0.27 in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.1->langchain-ibm==0.1.7) (0.28.1)
# Requirement already satisfied: urllib3 in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.1->langchain-ibm==0.1.7) (2.5.0)
# Requirement already satisfied: pandas<2.4.0,>=0.24.2 in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.1->langchain-ibm==0.1.7) (2.3.3)
# Requirement already satisfied: certifi in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.1->langchain-ibm==0.1.7) (2025.11.12)
# Collecting lomond (from ibm-watsonx-ai<2.0.0,>=1.0.1->langchain-ibm==0.1.7)
#   Downloading lomond-0.3.3-py2.py3-none-any.whl.metadata (4.1 kB)
# Collecting tabulate (from ibm-watsonx-ai<2.0.0,>=1.0.1->langchain-ibm==0.1.7)
#   Downloading tabulate-0.10.0-py3-none-any.whl.metadata (40 kB)
# Requirement already satisfied: packaging in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.1->langchain-ibm==0.1.7) (24.2)
# Collecting ibm-cos-sdk<2.15.0,>=2.12.0 (from ibm-watsonx-ai<2.0.0,>=1.0.1->langchain-ibm==0.1.7)
#   Downloading ibm_cos_sdk-2.14.3.tar.gz (58 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: cachetools in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.1->langchain-ibm==0.1.7) (6.2.2)
# Requirement already satisfied: anyio in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from httpx<0.29,>=0.27->ibm-watsonx-ai<2.0.0,>=1.0.1->langchain-ibm==0.1.7) (4.11.0)
# Requirement already satisfied: httpcore==1.* in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from httpx<0.29,>=0.27->ibm-watsonx-ai<2.0.0,>=1.0.1->langchain-ibm==0.1.7) (1.0.9)
# Requirement already satisfied: idna in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from httpx<0.29,>=0.27->ibm-watsonx-ai<2.0.0,>=1.0.1->langchain-ibm==0.1.7) (3.11)
# Requirement already satisfied: h11>=0.16 in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from httpcore==1.*->httpx<0.29,>=0.27->ibm-watsonx-ai<2.0.0,>=1.0.1->langchain-ibm==0.1.7) (0.16.0)
# Collecting ibm-cos-sdk-core==2.14.3 (from ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai<2.0.0,>=1.0.1->langchain-ibm==0.1.7)
#   Downloading ibm_cos_sdk_core-2.14.3.tar.gz (1.1 MB)
#      ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#      --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#      ---------------------------- ----------- 0.8/1.1 MB 2.2 MB/s eta 0:00:01
#      ---------------------------- ----------- 0.8/1.1 MB 2.2 MB/s eta 0:00:01
#      ---------------------------- ----------- 0.8/1.1 MB 2.2 MB/s eta 0:00:01
#      -------------------------------------- - 1.0/1.1 MB 959.0 kB/s eta 0:00:01
#      ---------------------------------------- 1.1/1.1 MB 920.6 kB/s  0:00:01
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting ibm-cos-sdk-s3transfer==2.14.3 (from ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai<2.0.0,>=1.0.1->langchain-ibm==0.1.7)
#   Downloading ibm_cos_sdk_s3transfer-2.14.3.tar.gz (139 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting jmespath<=1.0.1,>=0.10.0 (from ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai<2.0.0,>=1.0.1->langchain-ibm==0.1.7)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0 in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from ibm-cos-sdk-core==2.14.3->ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai<2.0.0,>=1.0.1->langchain-ibm==0.1.7) (2.9.0.post0)
# Requirement already satisfied: PyYAML>=5.3 in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from langchain-core<0.3,>=0.1.50->langchain-ibm==0.1.7) (6.0.3)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.3,>=0.1.50->langchain-ibm==0.1.7)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langsmith<0.2.0,>=0.1.112 (from langchain-core<0.3,>=0.1.50->langchain-ibm==0.1.7)
#   Downloading langsmith-0.1.147-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from langchain-core<0.3,>=0.1.50->langchain-ibm==0.1.7) (2.12.4)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from langchain-core<0.3,>=0.1.50->langchain-ibm==0.1.7) (8.2.3)
# Requirement already satisfied: typing-extensions>=4.7 in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from langchain-core<0.3,>=0.1.50->langchain-ibm==0.1.7) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3,>=0.1.50->langchain-ibm==0.1.7) (3.1.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.1.50->langchain-ibm==0.1.7) (3.11.4)
# Collecting requests-toolbelt<2.0.0,>=1.0.0 (from langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.1.50->langchain-ibm==0.1.7)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pandas<2.4.0,>=0.24.2->ibm-watsonx-ai<2.0.0,>=1.0.1->langchain-ibm==0.1.7) (2.3.5)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pandas<2.4.0,>=0.24.2->ibm-watsonx-ai<2.0.0,>=1.0.1->langchain-ibm==0.1.7) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pandas<2.4.0,>=0.24.2->ibm-watsonx-ai<2.0.0,>=1.0.1->langchain-ibm==0.1.7) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.3,>=0.1.50->langchain-ibm==0.1.7) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.3,>=0.1.50->langchain-ibm==0.1.7) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.3,>=0.1.50->langchain-ibm==0.1.7) (0.4.2)
# Requirement already satisfied: six>=1.5 in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from python-dateutil<3.0.0,>=2.9.0->ibm-cos-sdk-core==2.14.3->ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai<2.0.0,>=1.0.1->langchain-ibm==0.1.7) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from requests->ibm-watsonx-ai<2.0.0,>=1.0.1->langchain-ibm==0.1.7) (3.4.4)
# Requirement already satisfied: sniffio>=1.1 in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from anyio->httpx<0.29,>=0.27->ibm-watsonx-ai<2.0.0,>=1.0.1->langchain-ibm==0.1.7) (1.3.1)
# Downloading langchain_ibm-0.1.7-py3-none-any.whl (9.8 kB)
# Downloading ibm_watsonx_ai-1.7.2-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    ------------------ --------------------- 0.5/1.1 MB 1.5 MB/s eta 0:00:01
#    ------------------ --------------------- 0.5/1.1 MB 1.5 MB/s eta 0:00:01
#    --------------------------- ------------ 0.8/1.1 MB 869.7 kB/s eta 0:00:01
#    --------------------------- ------------ 0.8/1.1 MB 869.7 kB/s eta 0:00:01
#    --------------------------- ------------ 0.8/1.1 MB 869.7 kB/s eta 0:00:01
#    ---------------------------------------- 1.1/1.1 MB 690.7 kB/s  0:00:01
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading langchain_core-0.2.43-py3-none-any.whl (397 kB)
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langsmith-0.1.147-py3-none-any.whl (311 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading lomond-0.3.3-py2.py3-none-any.whl (35 kB)
# Downloading tabulate-0.10.0-py3-none-any.whl (39 kB)
# Building wheels for collected packages: ibm-cos-sdk, ibm-cos-sdk-core, ibm-cos-sdk-s3transfer
#   Building wheel for ibm-cos-sdk (pyproject.toml): started
#   Building wheel for ibm-cos-sdk (pyproject.toml): finished with status 'done'
#   Created wheel for ibm-cos-sdk: filename=ibm_cos_sdk-2.14.3-py3-none-any.whl size=77348 sha256=fc236692f28e6e03e499151e0d3fb7bb7d97917d563b6a33e7ec5840b8f29d21
#   Stored in directory: c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local\pip\cache\wheels\a2\99\26\abae30f0704d74b848aac9aac73e9b47977b808a75a5a984fe
#   Building wheel for ibm-cos-sdk-core (pyproject.toml): started
#   Building wheel for ibm-cos-sdk-core (pyproject.toml): finished with status 'done'
#   Created wheel for ibm-cos-sdk-core: filename=ibm_cos_sdk_core-2.14.3-py3-none-any.whl size=662221 sha256=648068930cb2d63b58df54a0698ba2e561dfede2ecebece63a5b77427463bc3e
#   Stored in directory: c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local\pip\cache\wheels\47\62\69\1e99fea95b82e8dbd4ea97e78160224269774a43883f908551
#   Building wheel for ibm-cos-sdk-s3transfer (pyproject.toml): started
#   Building wheel for ibm-cos-sdk-s3transfer (pyproject.toml): finished with status 'done'
#   Created wheel for ibm-cos-sdk-s3transfer: filename=ibm_cos_sdk_s3transfer-2.14.3-py3-none-any.whl size=90322 sha256=a0df9d4415c3899695669dbc74131da4c882d28c7df610eb4d72b2fcf922505c
#   Stored in directory: c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local\pip\cache\wheels\a4\41\53\4fdc180f2fe8bd53f98fd46d071708bfa93db0339af2ebd6ad
# Successfully built ibm-cos-sdk ibm-cos-sdk-core ibm-cos-sdk-s3transfer
# Installing collected packages: tabulate, lomond, jsonpatch, jmespath, requests-toolbelt, ibm-cos-sdk-core, langsmith, ibm-cos-sdk-s3transfer, langchain-core, ibm-cos-sdk, ibm-watsonx-ai, langchain-ibm
#
#    --- ------------------------------------  1/12 [lomond]
#    ---------- -----------------------------  3/12 [jmespath]
#    ------------- --------------------------  4/12 [requests-toolbelt]
#    ---------------- -----------------------  5/12 [ibm-cos-sdk-core]
#    ---------------- -----------------------  5/12 [ibm-cos-sdk-core]
#    ---------------- -----------------------  5/12 [ibm-cos-sdk-core]
#    ---------------- -----------------------  5/12 [ibm-cos-sdk-core]
#    -------------------- -------------------  6/12 [langsmith]
#    -------------------- -------------------  6/12 [langsmith]
#    ----------------------- ----------------  7/12 [ibm-cos-sdk-s3transfer]
#    -------------------------- -------------  8/12 [langchain-core]
#    -------------------------- -------------  8/12 [langchain-core]
#    -------------------------- -------------  8/12 [langchain-core]
#    -------------------------- -------------  8/12 [langchain-core]
#    -------------------------- -------------  8/12 [langchain-core]
#    -------------------------- -------------  8/12 [langchain-core]
#    -------------------------- -------------  8/12 [langchain-core]
#    -------------------------- -------------  8/12 [langchain-core]
#    -------------------------- -------------  8/12 [langchain-core]
#    -------------------------- -------------  8/12 [langchain-core]
#    -------------------------- -------------  8/12 [langchain-core]
#    ------------------------------ ---------  9/12 [ibm-cos-sdk]
#    --------------------------------- ------ 10/12 [ibm-watsonx-ai]
#    --------------------------------- ------ 10/12 [ibm-watsonx-ai]
#    --------------------------------- ------ 10/12 [ibm-watsonx-ai]
#    --------------------------------- ------ 10/12 [ibm-watsonx-ai]
#    --------------------------------- ------ 10/12 [ibm-watsonx-ai]
#    --------------------------------- ------ 10/12 [ibm-watsonx-ai]
#    --------------------------------- ------ 10/12 [ibm-watsonx-ai]
#    --------------------------------- ------ 10/12 [ibm-watsonx-ai]
#    --------------------------------- ------ 10/12 [ibm-watsonx-ai]
#    --------------------------------- ------ 10/12 [ibm-watsonx-ai]
#    --------------------------------- ------ 10/12 [ibm-watsonx-ai]
#    --------------------------------- ------ 10/12 [ibm-watsonx-ai]
#    --------------------------------- ------ 10/12 [ibm-watsonx-ai]
#    --------------------------------- ------ 10/12 [ibm-watsonx-ai]
#    --------------------------------- ------ 10/12 [ibm-watsonx-ai]
#    --------------------------------- ------ 10/12 [ibm-watsonx-ai]
#    --------------------------------- ------ 10/12 [ibm-watsonx-ai]
#    --------------------------------- ------ 10/12 [ibm-watsonx-ai]
#    --------------------------------- ------ 10/12 [ibm-watsonx-ai]
#    --------------------------------- ------ 10/12 [ibm-watsonx-ai]
#    --------------------------------- ------ 10/12 [ibm-watsonx-ai]
#    --------------------------------- ------ 10/12 [ibm-watsonx-ai]
#    --------------------------------- ------ 10/12 [ibm-watsonx-ai]
#    --------------------------------- ------ 10/12 [ibm-watsonx-ai]
#    ------------------------------------ --- 11/12 [langchain-ibm]
#    ---------------------------------------- 12/12 [langchain-ibm]
#
# Successfully installed ibm-cos-sdk-2.14.3 ibm-cos-sdk-core-2.14.3 ibm-cos-sdk-s3transfer-2.14.3 ibm-watsonx-ai-1.7.2 jmespath-1.0.1 jsonpatch-1.33 langchain-core-0.2.43 langchain-ibm-0.1.7 langsmith-0.1.147 lomond-0.3.3 requests-toolbelt-1.0.0 tabulate-0.10.0
#   WARNING: The script tabulate.exe is installed in 'C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script langsmith.exe is installed in 'C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: C:\Users\Dell\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Collecting langchain-community==0.2.10
#   Downloading langchain_community-0.2.10-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: PyYAML>=5.3 in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from langchain-community==0.2.10) (6.0.3)
# Collecting SQLAlchemy<3,>=1.4 (from langchain-community==0.2.10)
#   Downloading sqlalchemy-2.0.52-cp313-cp313-win_amd64.whl.metadata (9.9 kB)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain-community==0.2.10)
#   Downloading aiohttp-3.14.3-cp313-cp313-win_amd64.whl.metadata (8.5 kB)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community==0.2.10)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting langchain<0.3.0,>=0.2.9 (from langchain-community==0.2.10)
#   Downloading langchain-0.2.17-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.23 in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from langchain-community==0.2.10) (0.2.43)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from langchain-community==0.2.10) (0.1.147)
# Collecting numpy<2.0.0,>=1.26.0 (from langchain-community==0.2.10)
#   Using cached numpy-1.26.4.tar.gz (15.8 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [21 lines of output]
#       + C:\Users\Dell\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe C:\Users\Dell\AppData\Local\Temp\pip-install-r2558g_u\numpy_fd965a62801041ee9eec31e8a48cecc2\vendored-meson\meson\meson.py setup C:\Users\Dell\AppData\Local\Temp\pip-install-r2558g_u\numpy_fd965a62801041ee9eec31e8a48cecc2 C:\Users\Dell\AppData\Local\Temp\pip-install-r2558g_u\numpy_fd965a62801041ee9eec31e8a48cecc2\.mesonpy-cysj25h5 -Dbuildtype=release -Db_ndebug=if-release -Db_vscrt=md --native-file=C:\Users\Dell\AppData\Local\Temp\pip-install-r2558g_u\numpy_fd965a62801041ee9eec31e8a48cecc2\.mesonpy-cysj25h5\meson-python-native-file.ini
#       The Meson build system
#       Version: 1.2.99
#       Source dir: C:\Users\Dell\AppData\Local\Temp\pip-install-r2558g_u\numpy_fd965a62801041ee9eec31e8a48cecc2
#       Build dir: C:\Users\Dell\AppData\Local\Temp\pip-install-r2558g_u\numpy_fd965a62801041ee9eec31e8a48cecc2\.mesonpy-cysj25h5
#       Build type: native build
#       Project name: NumPy
#       Project version: 1.26.4
#       WARNING: Failed to activate VS environment: Could not parse vswhere.exe output
#
#       ..\meson.build:1:0: ERROR: Unknown compiler(s): [['icl'], ['cl'], ['cc'], ['gcc'], ['clang'], ['clang-cl'], ['pgcc']]
#       The following exception(s) were encountered:
#       Running `icl ""` gave "[WinError 2] The system cannot find the file specified"
#       Running `cl /?` gave "[WinError 2] The system cannot find the file specified"
#       Running `cc --version` gave "[WinError 2] The system cannot find the file specified"
#       Running `gcc --version` gave "[WinError 2] The system cannot find the file specified"
#       Running `clang --version` gave "[WinError 2] The system cannot find the file specified"
#       Running `clang-cl /?` gave "[WinError 2] The system cannot find the file specified"
#       Running `pgcc --version` gave "[WinError 2] The system cannot find the file specified"
#
#       A full log can be found at C:\Users\Dell\AppData\Local\Temp\pip-install-r2558g_u\numpy_fd965a62801041ee9eec31e8a48cecc2\.mesonpy-cysj25h5\meson-logs\meson-log.txt
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: C:\Users\Dell\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> numpy
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Collecting langchain-experimental==0.0.62
#   Downloading langchain_experimental-0.0.62-py3-none-any.whl.metadata (1.5 kB)
# Collecting langchain-community<0.3.0,>=0.2.6 (from langchain-experimental==0.0.62)
#   Downloading langchain_community-0.2.19-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.10 in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from langchain-experimental==0.0.62) (0.2.43)
# Requirement already satisfied: PyYAML>=5.3 in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from langchain-community<0.3.0,>=0.2.6->langchain-experimental==0.0.62) (6.0.3)
# Collecting SQLAlchemy<3,>=1.4 (from langchain-community<0.3.0,>=0.2.6->langchain-experimental==0.0.62)
#   Using cached sqlalchemy-2.0.52-cp313-cp313-win_amd64.whl.metadata (9.9 kB)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain-community<0.3.0,>=0.2.6->langchain-experimental==0.0.62)
#   Using cached aiohttp-3.14.3-cp313-cp313-win_amd64.whl.metadata (8.5 kB)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community<0.3.0,>=0.2.6->langchain-experimental==0.0.62)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting langchain<0.3.0,>=0.2.17 (from langchain-community<0.3.0,>=0.2.6->langchain-experimental==0.0.62)
#   Using cached langchain-0.2.17-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.112 in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from langchain-community<0.3.0,>=0.2.6->langchain-experimental==0.0.62) (0.1.147)
# Collecting numpy<2.0.0,>=1.26.0 (from langchain-community<0.3.0,>=0.2.6->langchain-experimental==0.0.62)
#   Using cached numpy-1.26.4.tar.gz (15.8 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [21 lines of output]
#       + C:\Users\Dell\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe C:\Users\Dell\AppData\Local\Temp\pip-install-v9vfa42n\numpy_9bc5cd1235434e0ba0996fe25626ee85\vendored-meson\meson\meson.py setup C:\Users\Dell\AppData\Local\Temp\pip-install-v9vfa42n\numpy_9bc5cd1235434e0ba0996fe25626ee85 C:\Users\Dell\AppData\Local\Temp\pip-install-v9vfa42n\numpy_9bc5cd1235434e0ba0996fe25626ee85\.mesonpy-riisa_96 -Dbuildtype=release -Db_ndebug=if-release -Db_vscrt=md --native-file=C:\Users\Dell\AppData\Local\Temp\pip-install-v9vfa42n\numpy_9bc5cd1235434e0ba0996fe25626ee85\.mesonpy-riisa_96\meson-python-native-file.ini
#       The Meson build system
#       Version: 1.2.99
#       Source dir: C:\Users\Dell\AppData\Local\Temp\pip-install-v9vfa42n\numpy_9bc5cd1235434e0ba0996fe25626ee85
#       Build dir: C:\Users\Dell\AppData\Local\Temp\pip-install-v9vfa42n\numpy_9bc5cd1235434e0ba0996fe25626ee85\.mesonpy-riisa_96
#       Build type: native build
#       Project name: NumPy
#       Project version: 1.26.4
#       WARNING: Failed to activate VS environment: Could not parse vswhere.exe output
#
#       ..\meson.build:1:0: ERROR: Unknown compiler(s): [['icl'], ['cl'], ['cc'], ['gcc'], ['clang'], ['clang-cl'], ['pgcc']]
#       The following exception(s) were encountered:
#       Running `icl ""` gave "[WinError 2] The system cannot find the file specified"
#       Running `cl /?` gave "[WinError 2] The system cannot find the file specified"
#       Running `cc --version` gave "[WinError 2] The system cannot find the file specified"
#       Running `gcc --version` gave "[WinError 2] The system cannot find the file specified"
#       Running `clang --version` gave "[WinError 2] The system cannot find the file specified"
#       Running `clang-cl /?` gave "[WinError 2] The system cannot find the file specified"
#       Running `pgcc --version` gave "[WinError 2] The system cannot find the file specified"
#
#       A full log can be found at C:\Users\Dell\AppData\Local\Temp\pip-install-v9vfa42n\numpy_9bc5cd1235434e0ba0996fe25626ee85\.mesonpy-riisa_96\meson-logs\meson-log.txt
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: C:\Users\Dell\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> numpy
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Collecting langchainhub==0.1.18
#   Downloading langchainhub-0.1.18-py3-none-any.whl.metadata (621 bytes)
# Requirement already satisfied: requests<3,>=2 in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from langchainhub==0.1.18) (2.32.5)
# Collecting types-requests<3.0.0.0,>=2.31.0.2 (from langchainhub==0.1.18)
#   Downloading types_requests-2.33.0.20260906-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from requests<3,>=2->langchainhub==0.1.18) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from requests<3,>=2->langchainhub==0.1.18) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from requests<3,>=2->langchainhub==0.1.18) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from requests<3,>=2->langchainhub==0.1.18) (2025.11.12)
# Downloading langchainhub-0.1.18-py3-none-any.whl (4.8 kB)
# Downloading types_requests-2.33.0.20260906-py3-none-any.whl (21 kB)
# Installing collected packages: types-requests, langchainhub
#
#    ---------------------------------------- 2/2 [langchainhub]
#
# Successfully installed langchainhub-0.1.18 types-requests-2.33.0.20260906
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: C:\Users\Dell\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Collecting langchain==0.2.11
#   Downloading langchain-0.2.11-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: PyYAML>=5.3 in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from langchain==0.2.11) (6.0.3)
# Collecting SQLAlchemy<3,>=1.4 (from langchain==0.2.11)
#   Using cached sqlalchemy-2.0.52-cp313-cp313-win_amd64.whl.metadata (9.9 kB)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain==0.2.11)
#   Using cached aiohttp-3.14.3-cp313-cp313-win_amd64.whl.metadata (8.5 kB)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.23 in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from langchain==0.2.11) (0.2.43)
# Collecting langchain-text-splitters<0.3.0,>=0.2.0 (from langchain==0.2.11)
#   Downloading langchain_text_splitters-0.2.4-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from langchain==0.2.11) (0.1.147)
# Collecting numpy<2.0.0,>=1.26.0 (from langchain==0.2.11)
#   Using cached numpy-1.26.4.tar.gz (15.8 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [21 lines of output]
#       + C:\Users\Dell\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe C:\Users\Dell\AppData\Local\Temp\pip-install-rsxi1x3k\numpy_b710d54b14f24e9e85c9c2418229bd6d\vendored-meson\meson\meson.py setup C:\Users\Dell\AppData\Local\Temp\pip-install-rsxi1x3k\numpy_b710d54b14f24e9e85c9c2418229bd6d C:\Users\Dell\AppData\Local\Temp\pip-install-rsxi1x3k\numpy_b710d54b14f24e9e85c9c2418229bd6d\.mesonpy-a1jvfu0h -Dbuildtype=release -Db_ndebug=if-release -Db_vscrt=md --native-file=C:\Users\Dell\AppData\Local\Temp\pip-install-rsxi1x3k\numpy_b710d54b14f24e9e85c9c2418229bd6d\.mesonpy-a1jvfu0h\meson-python-native-file.ini
#       The Meson build system
#       Version: 1.2.99
#       Source dir: C:\Users\Dell\AppData\Local\Temp\pip-install-rsxi1x3k\numpy_b710d54b14f24e9e85c9c2418229bd6d
#       Build dir: C:\Users\Dell\AppData\Local\Temp\pip-install-rsxi1x3k\numpy_b710d54b14f24e9e85c9c2418229bd6d\.mesonpy-a1jvfu0h
#       Build type: native build
#       Project name: NumPy
#       Project version: 1.26.4
#       WARNING: Failed to activate VS environment: Could not parse vswhere.exe output
#
#       ..\meson.build:1:0: ERROR: Unknown compiler(s): [['icl'], ['cl'], ['cc'], ['gcc'], ['clang'], ['clang-cl'], ['pgcc']]
#       The following exception(s) were encountered:
#       Running `icl ""` gave "[WinError 2] The system cannot find the file specified"
#       Running `cl /?` gave "[WinError 2] The system cannot find the file specified"
#       Running `cc --version` gave "[WinError 2] The system cannot find the file specified"
#       Running `gcc --version` gave "[WinError 2] The system cannot find the file specified"
#       Running `clang --version` gave "[WinError 2] The system cannot find the file specified"
#       Running `clang-cl /?` gave "[WinError 2] The system cannot find the file specified"
#       Running `pgcc --version` gave "[WinError 2] The system cannot find the file specified"
#
#       A full log can be found at C:\Users\Dell\AppData\Local\Temp\pip-install-rsxi1x3k\numpy_b710d54b14f24e9e85c9c2418229bd6d\.mesonpy-a1jvfu0h\meson-logs\meson-log.txt
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: C:\Users\Dell\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> numpy
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Collecting pypdf==4.2.0
#   Downloading pypdf-4.2.0-py3-none-any.whl.metadata (7.4 kB)
# ...
# Collecting huggingface-hub<2.0,>=0.16.4 (from tokenizers>=0.13.2->chromadb==0.4.24)
#   Downloading huggingface_hub-1.31.0-py3-none-any.whl.metadata (16 kB)
# Collecting click<9.0.0,>=8.4.2 (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb==0.4.24)
#   Downloading click-8.5.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting filelock>=3.10.0 (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb==0.4.24)
#   Downloading filelock-3.32.6-py3-none-any.whl.metadata (2.0 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb==0.4.24)
#   Downloading fsspec-2026.7.0-py3-none-any.whl.metadata (10 kB)
# Collecting hf-xet<2.0.0,>=1.5.2 (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb==0.4.24)
#   Downloading hf_xet-1.6.0-cp38-abi3-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb==0.4.24) (0.28.1)
# Requirement already satisfied: httpcore==1.* in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb==0.4.24) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb==0.4.24) (0.16.0)
# Collecting shellingham>=1.3.0 (from typer>=0.9.0->chromadb==0.4.24)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=13.8.0 (from typer>=0.9.0->chromadb==0.4.24)
#   Downloading rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=13.8.0->typer>=0.9.0->chromadb==0.4.24)
#   Downloading markdown_it_py-4.2.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from rich>=13.8.0->typer>=0.9.0->chromadb==0.4.24) (2.21.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=13.8.0->typer>=0.9.0->chromadb==0.4.24)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb==0.4.24)
#   Downloading httptools-0.8.0-cp313-cp313-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: python-dotenv>=0.13 in C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.24) (1.2.1)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb==0.4.24)
#   Downloading watchfiles-1.2.0-cp313-cp313-win_amd64.whl.metadata (5.0 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb==0.4.24)
#   Downloading websockets-17.1-cp313-cp313-win_amd64.whl.metadata (6.5 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib->kubernetes>=28.1.0->chromadb==0.4.24)
#   Downloading oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Downloading chromadb-0.4.24-py3-none-any.whl (525 kB)
#    ---------------------------------------- 0.0/525.5 kB ? eta -:--:--
#    ------------------- -------------------- 262.1/525.5 kB ? eta -:--:--
#    ---------------------------------------- 525.5/525.5 kB 1.7 MB/s  0:00:00
# Downloading bcrypt-5.0.0-cp39-abi3-win_amd64.whl (150 kB)
# Downloading build-1.6.1-py3-none-any.whl (31 kB)
# Downloading grpcio-1.84.0-cp313-cp313-win_amd64.whl (5.3 MB)
#    ---------------------------------------- 0.0/5.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/5.3 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/5.3 MB 1.6 MB/s eta 0:00:03
#    ------- -------------------------------- 1.0/5.3 MB 1.7 MB/s eta 0:00:03
#    ----------- ---------------------------- 1.6/5.3 MB 2.0 MB/s eta 0:00:02
#    ------------- -------------------------- 1.8/5.3 MB 2.0 MB/s eta 0:00:02
#    ----------------- ---------------------- 2.4/5.3 MB 1.9 MB/s eta 0:00:02
#    ------------------- -------------------- 2.6/5.3 MB 1.8 MB/s eta 0:00:02
#    ------------------- -------------------- 2.6/5.3 MB 1.8 MB/s eta 0:00:02
#    --------------------- ------------------ 2.9/5.3 MB 1.6 MB/s eta 0:00:02
#    ----------------------- ---------------- 3.1/5.3 MB 1.6 MB/s eta 0:00:02
#    ------------------------- -------------- 3.4/5.3 MB 1.6 MB/s eta 0:00:02
#    ----------------------------- ---------- 3.9/5.3 MB 1.5 MB/s eta 0:00:01
#    --------------------------------- ------ 4.5/5.3 MB 1.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 4.7/5.3 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 5.3/5.3 MB 1.6 MB/s  0:00:03
# Downloading kubernetes-36.0.3-py2.py3-none-any.whl (4.6 MB)
#    ---------------------------------------- 0.0/4.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.6 MB ? eta -:--:--
#    ------ --------------------------------- 0.8/4.6 MB 2.1 MB/s eta 0:00:02
#    ----------- ---------------------------- 1.3/4.6 MB 2.2 MB/s eta 0:00:02
#    ------------- -------------------------- 1.6/4.6 MB 2.2 MB/s eta 0:00:02
#    ------------------ --------------------- 2.1/4.6 MB 2.2 MB/s eta 0:00:02
#    ---------------------- ----------------- 2.6/4.6 MB 2.2 MB/s eta 0:00:01
#    --------------------------- ------------ 3.1/4.6 MB 2.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 3.4/4.6 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 3.9/4.6 MB 2.2 MB/s eta 0:00:01
#    -------------------------------------- - 4.5/4.6 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 4.6/4.6 MB 2.0 MB/s  0:00:02
# Downloading aiohttp-3.14.3-cp313-cp313-win_amd64.whl (476 kB)
# Downloading multidict-6.8.0-cp313-cp313-win_amd64.whl (51 kB)
# Downloading yarl-1.24.5-cp313-cp313-win_amd64.whl (97 kB)
# Downloading aiohappyeyeballs-2.7.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading durationpy-0.11-py3-none-any.whl (4.1 kB)
# Downloading frozenlist-1.8.0-cp313-cp313-win_amd64.whl (43 kB)
# Downloading mmh3-5.3.0-cp313-cp313-win_amd64.whl (41 kB)
# Downloading onnxruntime-1.30.0-cp313-cp313-win_amd64.whl (14.3 MB)
#    ---------------------------------------- 0.0/14.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/14.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/14.3 MB 2.0 MB/s eta 0:00:07
#    -- ------------------------------------- 1.0/14.3 MB 2.0 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.6/14.3 MB 2.0 MB/s eta 0:00:07
#    ----- ---------------------------------- 2.1/14.3 MB 2.0 MB/s eta 0:00:06
#    ------- -------------------------------- 2.6/14.3 MB 2.1 MB/s eta 0:00:06
#    -------- ------------------------------- 2.9/14.3 MB 2.1 MB/s eta 0:00:06
#    --------- ------------------------------ 3.4/14.3 MB 2.1 MB/s eta 0:00:06
#    ---------- ----------------------------- 3.9/14.3 MB 2.1 MB/s eta 0:00:05
#    ------------ --------------------------- 4.5/14.3 MB 2.2 MB/s eta 0:00:05
#    ------------- -------------------------- 5.0/14.3 MB 2.2 MB/s eta 0:00:05
#    -------------- ------------------------- 5.2/14.3 MB 2.2 MB/s eta 0:00:05
#    ---------------- ----------------------- 5.8/14.3 MB 2.1 MB/s eta 0:00:04
#    ---------------- ----------------------- 6.0/14.3 MB 2.1 MB/s eta 0:00:04
#    ------------------ --------------------- 6.6/14.3 MB 2.1 MB/s eta 0:00:04
#    ------------------- -------------------- 7.1/14.3 MB 2.1 MB/s eta 0:00:04
#    -------------------- ------------------- 7.3/14.3 MB 2.1 MB/s eta 0:00:04
#    --------------------- ------------------ 7.9/14.3 MB 2.1 MB/s eta 0:00:04
#    ---------------------- ----------------- 8.1/14.3 MB 2.1 MB/s eta 0:00:03
#    ------------------------ --------------- 8.7/14.3 MB 2.1 MB/s eta 0:00:03
#    ------------------------ --------------- 8.9/14.3 MB 2.0 MB/s eta 0:00:03
#    -------------------------- ------------- 9.4/14.3 MB 2.0 MB/s eta 0:00:03
#    --------------------------- ------------ 9.7/14.3 MB 2.0 MB/s eta 0:00:03
#    ---------------------------- ----------- 10.2/14.3 MB 2.0 MB/s eta 0:00:03
#    ------------------------------ --------- 10.7/14.3 MB 2.0 MB/s eta 0:00:02
#    ------------------------------ --------- 11.0/14.3 MB 2.0 MB/s eta 0:00:02
#    -------------------------------- ------- 11.5/14.3 MB 2.0 MB/s eta 0:00:02
#    --------------------------------- ------ 12.1/14.3 MB 2.1 MB/s eta 0:00:02
#    ----------------------------------- ---- 12.6/14.3 MB 2.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 12.8/14.3 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------- -- 13.4/14.3 MB 2.1 MB/s eta 0:00:01
#    -------------------------------------- - 13.6/14.3 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------  14.2/14.3 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 14.3/14.3 MB 2.0 MB/s  0:00:07
# Downloading opentelemetry_api-1.44.0-py3-none-any.whl (60 kB)
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.44.0-py3-none-any.whl (19 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.44.0-py3-none-any.whl (17 kB)
# Downloading opentelemetry_proto-1.44.0-py3-none-any.whl (72 kB)
# Downloading googleapis_common_protos-1.75.3-py3-none-any.whl (306 kB)
# Downloading opentelemetry_sdk-1.44.0-py3-none-any.whl (137 kB)
# Downloading opentelemetry_semantic_conventions-0.65b0-py3-none-any.whl (204 kB)
# Downloading protobuf-7.36.1-cp310-abi3-win_amd64.whl (456 kB)
# Downloading opentelemetry_instrumentation_fastapi-0.65b0-py3-none-any.whl (13 kB)
# Downloading opentelemetry_instrumentation-0.65b0-py3-none-any.whl (36 kB)
# Downloading opentelemetry_instrumentation_asgi-0.65b0-py3-none-any.whl (15 kB)
# Downloading opentelemetry_util_http-0.65b0-py3-none-any.whl (8.2 kB)
# Downloading asgiref-3.12.1-py3-none-any.whl (25 kB)
# Downloading wrapt-2.4.1-cp313-cp313-win_amd64.whl (98 kB)
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading posthog-7.53.0-py3-none-any.whl (662 kB)
#    ---------------------------------------- 0.0/662.8 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/662.8 kB ? eta -:--:--
#    ------------------------------- -------- 524.3/662.8 kB 1.6 MB/s eta 0:00:01
#    ------------------------------- -------- 524.3/662.8 kB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 662.8/662.8 kB 590.2 kB/s  0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading propcache-0.5.2-cp313-cp313-win_amd64.whl (41 kB)
# Downloading pulsar_client-3.13.0-cp313-cp313-win_amd64.whl (3.9 MB)
#    ---------------------------------------- 0.0/3.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.9 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/3.9 MB 1.3 MB/s eta 0:00:03
#    ------- -------------------------------- 0.8/3.9 MB 1.3 MB/s eta 0:00:03
#    ---------- ----------------------------- 1.0/3.9 MB 1.5 MB/s eta 0:00:02
#    --------------- ------------------------ 1.6/3.9 MB 1.7 MB/s eta 0:00:02
#    --------------------- ------------------ 2.1/3.9 MB 1.8 MB/s eta 0:00:02
#    ----------------------- ---------------- 2.4/3.9 MB 1.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 2.9/3.9 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 3.4/3.9 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------  3.9/3.9 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 3.9/3.9 MB 1.9 MB/s  0:00:02
# Downloading pypika-0.51.1-py2.py3-none-any.whl (60 kB)
# Downloading tokenizers-0.23.2-cp310-abi3-win_amd64.whl (2.9 MB)
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.9 MB ? eta -:--:--
#    ---------- ----------------------------- 0.8/2.9 MB 1.9 MB/s eta 0:00:02
#    -------------- ------------------------- 1.0/2.9 MB 1.8 MB/s eta 0:00:02
#    --------------------- ------------------ 1.6/2.9 MB 1.9 MB/s eta 0:00:01
#    ------------------------- -------------- 1.8/2.9 MB 1.9 MB/s eta 0:00:01
#    -------------------------------- ------- 2.4/2.9 MB 1.9 MB/s eta 0:00:01
#    ------------------------------------ --- 2.6/2.9 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.9/2.9 MB 1.9 MB/s  0:00:01
# Downloading huggingface_hub-1.31.0-py3-none-any.whl (798 kB)
#    ---------------------------------------- 0.0/798.3 kB ? eta -:--:--
#    ------------- -------------------------- 262.1/798.3 kB ? eta -:--:--
#    -------------------------- ------------- 524.3/798.3 kB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 798.3/798.3 kB 1.8 MB/s  0:00:00
# Downloading click-8.5.0-py3-none-any.whl (125 kB)
# Downloading hf_xet-1.6.0-cp38-abi3-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.0 MB ? eta -:--:--
#    ------- -------------------------------- 0.8/4.0 MB 2.0 MB/s eta 0:00:02
#    ---------- ----------------------------- 1.0/4.0 MB 2.0 MB/s eta 0:00:02
#    --------------- ------------------------ 1.6/4.0 MB 2.0 MB/s eta 0:00:02
#    ------------------ --------------------- 1.8/4.0 MB 2.0 MB/s eta 0:00:02
#    ----------------------- ---------------- 2.4/4.0 MB 2.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 2.9/4.0 MB 2.0 MB/s eta 0:00:01
#    ------------------------------- -------- 3.1/4.0 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------ --- 3.7/4.0 MB 2.0 MB/s eta 0:00:01
#    -------------------------------------- - 3.9/4.0 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 1.9 MB/s  0:00:02
# Downloading filelock-3.32.6-py3-none-any.whl (100 kB)
# Downloading fsspec-2026.7.0-py3-none-any.whl (206 kB)
# Downloading typer-0.27.2-py3-none-any.whl (123 kB)
# Downloading rich-15.0.0-py3-none-any.whl (310 kB)
# Downloading markdown_it_py-4.2.0-py3-none-any.whl (91 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading httptools-0.8.0-cp313-cp313-win_amd64.whl (90 kB)
# Downloading watchfiles-1.2.0-cp313-cp313-win_amd64.whl (288 kB)
# Downloading websockets-17.1-cp313-cp313-win_amd64.whl (217 kB)
# Downloading flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Downloading importlib_resources-7.1.0-py3-none-any.whl (37 kB)
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Downloading oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Building wheels for collected packages: chroma-hnswlib
#   Building wheel for chroma-hnswlib (pyproject.toml): started
#   Building wheel for chroma-hnswlib (pyproject.toml): finished with status 'error'
# Failed to build chroma-hnswlib
#   error: subprocess-exited-with-error
#
#   × Building wheel for chroma-hnswlib (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [5 lines of output]
#       running bdist_wheel
#       running build
#       running build_ext
#       building 'hnswlib' extension
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for chroma-hnswlib
#
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: C:\Users\Dell\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# error: failed-wheel-build-for-install
#
# × Failed to build installable wheels for some pyproject.toml based projects
# ╰─> chroma-hnswlib

# %%
import os
os._exit(00)

# %%
# You can also use this section to suppress warnings generated by your code:
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
warnings.filterwarnings('ignore')
import os
os.environ['ANONYMIZED_TELEMETRY'] = 'False'

from ibm_watsonx_ai.foundation_models import ModelInference
from ibm_watsonx_ai.metanames import GenTextParamsMetaNames as GenParams
from ibm_watsonx_ai.foundation_models.utils.enums import ModelTypes
from ibm_watson_machine_learning.foundation_models.extensions.langchain import WatsonxLLM

# %%
model_id = 'ibm/granite-4-h-small' 

parameters = {
    GenParams.MAX_NEW_TOKENS: 256,  # this controls the maximum number of tokens in the generated output
    GenParams.TEMPERATURE: 0.2, # this randomness or creativity of the model's responses 
}

credentials = {
    "url": "https://us-south.ml.cloud.ibm.com"
    # "api_key": "your api key here"
    # uncomment above and fill in the API key when running locally
}

project_id = "skills-network"

model = ModelInference(
    model_id=model_id,
    params=parameters,
    credentials=credentials,
    project_id=project_id
)
model

# %%
msg = model.generate("In today's sales meeting, we ")
print(msg['results'][0]['generated_text'])
# Out:
#  discussed the importance of effective communication in sales. We explored various techniques to improve our communication skills, such as active listening, asking open-ended questions, and using clear and concise language. We also emphasized the need to adapt our communication style to different clients and situations. The meeting concluded with a role-playing exercise to practice these skills.

# %%
llama_llm = WatsonxLLM(model = model)

# %%
print(llama_llm.invoke("Who is man's best friend?"))
# Out:
#  It's a dog, of course. Dogs have been living with man for thousands of years. Scientists believe that dogs are descended from the wild wolf. The dog was the first animal to be tamed by man. As early as 14,000 years ago, people began to raise dogs. From the beginning, dogs were man's helper and protector. Over the years, people have developed many different breeds of dogs. There are water dogs, mountain dogs, farm dogs and house dogs. There are big dogs and little dogs. Some dogs have lots of hair. Others have almost none. Each breed of dog is different, but they are all members of the family Canidae. Dogs are known as "man's best friend". Why? Because they are loyal, loving and intelligent. They are more like us than any other animal on earth. Today, people use dogs in many ways. Dogs help the police, the army and people in need. Dogs can help blind people get around. They can help the police find bad people or dangerous things. They can even do tricks to make us laugh and forget our troubles. Maybe that's why we love dogs so much. They make our lives better.

# %%
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage

# %%
msg = llama_llm.invoke(
    [
        SystemMessage(content="You are a helpful AI bot that assists a user in choosing the perfect book to read in one short sentence"),
        HumanMessage(content="I enjoy mystery novels, what should I read?")
    ]
)

# %%
print(msg)

# %%
msg = llama_llm.invoke(
    [
        SystemMessage(content="You are a supportive AI bot that suggests fitness activities to a user in one short sentence"),
        HumanMessage(content="I like high-intensity workouts, what should I do?"),
        AIMessage(content="You should try a CrossFit class"),
        HumanMessage(content="How often should I attend?")
    ]
)

# %%
print(msg)

# %%
msg = llama_llm.invoke(
    [
        HumanMessage(content="What month follows June?")
    ]
)

# %%
print(msg)

# %%
# Define different parameter sets
parameters_creative = {
    GenParams.MAX_NEW_TOKENS: 256,
    GenParams.TEMPERATURE: 0.8,  # Higher temperature for more creative responses
}

parameters_precise = {
    GenParams.MAX_NEW_TOKENS: 256,
    GenParams.TEMPERATURE: 0.1,  # Lower temperature for more deterministic responses
}

# Define the model ID for ibm/granite-4-h-small
granite='ibm/granite-4-h-small'

# Define the model ID for llama-4-maverick-17b-128e-instruct-fp8
llama='meta-llama/llama-4-maverick-17b-128e-instruct-fp8'

# TODO: Send identical prompts to both models and compare the responses.
credentials = {
    "url": "https://us-south.ml.cloud.ibm.com"
    # "api_key": "your api key here"
    # uncomment above and fill in the API key when running locally
}

project_id = "skills-network"

model = ModelInference(
    model_id=granite,
    params=parameters,
    credentials=credentials,
    project_id=project_id
)
model
